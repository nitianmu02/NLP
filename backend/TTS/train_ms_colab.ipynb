# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import os
sys.path.append('/content/drive/My Drive/VITS/')
path="/content/drive/My Drive/VITS/"
os.chdir(path)

# %%
# !git remote add origin https://github.com/mark-hfut/VITS.git
# !git config --global user.email "1546662938@qq.com"
# !git config --global user.name "mark-hfut"
# !git pull https://github.com/mark-hfut/VITS.git

# %%
# !pip install -r requirements.txt

# os.chdir(path + './monotonic_align/')
# !python setup.py build_ext --inplace
# os.chdir(path)

# %%
# !python train_ms.py -c configs/genshin_base_ms.json -m genshin_base
# Out:
# ^C

# %%
# !nvidia-smi
# Out:
# Tue Oct  4 15:48:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P0    40W /  70W |      3MiB / 15109MiB |     19%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
